# %% [markdown]
# # Oct 10 2025

# %% [markdown]
# # First Code Work With Numbers

# %%
5
# Out:
# 5

# %%
5+3
# Out:
# 8

# %%
3+
# Out:
#   Cell In[3], line 1
#     3+
#       ^
# SyntaxError: invalid syntax

# %%
5+5
# Out:
# 10

# %%
_ + 5       # Underscore Actually Takes previous value output in VS Code here it is giving error
            # so we use another method
# Out:
# 15

# %%
Out[4]+5    # Out[4] = output of 4 the cell, Now it will give right result
# Out:
# 15

# %%
5+5*2-3
# Out:
# 12

# %%
(5+5)*2-3
# Out:
# 17

# %%
10+5
# Out:
# 15

# %%
10-5
# Out:
# 5

# %%
10*5
# Out:
# 50

# %%
10/5     # Float Division Means output has decimal
# Out:
# 2.0

# %%
10//5    # Integer Division
# Out:
# 2

# %%
55 % 3 # Remainder
# Out:
# 1

# %%
5*2
# Out:
# 10

# %%
5**2  # (5*5) Square
# Out:
# 25

# %%
5**3  #(5*5*5) Cube
# Out:
# 125

# %%
5**4    #(5*5*5*5)  5 power 4
# Out:
# 625

# %%
10*2
10+2
10-2   # Here Only Last Line we got the output
# Out:
# 8

# %%
# To Get All Lines Output
print(10*2)
print(10+2)
print(10-2)
# Out:
# 20
# 12
# 8

# %%
print("My Name is Siva Pulikonda. I am Studying FSDS With Gen AI and Agentic AI in Nareshit Under Prakash Senapathi Sir")
# Out:
# My Name is Siva Pulikonda. I am Studying FSDS With Gen AI and Agentic AI in Nareshit Under Prakash Senapathi Sir
