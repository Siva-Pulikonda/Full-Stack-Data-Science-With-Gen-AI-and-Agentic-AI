# %% [markdown]
# # Oct 29 2025

# %% [markdown]
# # Input()

# %%
x=input()    # when you execute this a prompt tab will open, enter any x value and press enter
x
# Out:
#  5
# '5'

# %%
x=input()    # Here we will get two prompt tabs, you will enter two values but you still got wrong answer why ?
y=input()    

z=x+y

print(z)
# Out:
#  5
#  6
# 56

# %%
# Input() function by default it will read string only
print(type(x))
# Out:
# <class 'str'>

# %% [markdown]
# # Index With Numbers

# %%
x1=int(input('enter the first number'))    # By changing string to interger using typecasting we can get the correct output
y1=int(input('enter the second number'))

z1=x1+y1
print(z1)
# Out:
# enter the first number 5
# enter the second number 6
# 11

# %%
print(type(x1))    # now you see the class is integer
# Out:
# <class 'int'>

# %%
x2=input('Username')
y2=input('Password')

z2=x2+y2
print(z2)         # i have used a space after siva_ so we got space in the output
# Out:
# Username Siva
# Password Pulikonda
# Siva Pulikonda

# %% [markdown]
# # Input with String

# %%
st=input('Enter a String')
print(st)
# Out:
# Enter a String HelloSivaPulikonda
# HelloSivaPulikonda

# %% [markdown]
# # Input With Index

# %%
st
# Out:
# 'HelloSivaPulikonda'

# %%
print(st[9])
# Out:
# P

# %%
print(st[0:10])
# Out:
# HelloSivaP

# %%
print(st[15])
# Out:
# n

# %%
print(st[-1])
# Out:
# a

# %%
st=input('enter a string')[4]  
print(st)
# Out:
# enter a string Pulikonda
# k

# %% [markdown]
# # Input With Slicing

# %%
st=input('enter a string')[8:13]   # Indexing in input function
print(st)
# Out:
# enter a string 1234567891011
# 91011

# %% [markdown]
# # Input With Expression

# %%
re=int(input('enter an expression'))
print(re)    # even though i have given int it is throwing me error
             # so we use eval function for handling expressions
# Out:
# enter an expression 5+8-3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 re=int(input('enter an expression'))
#       2 print(re)
#
# ValueError: invalid literal for int() with base 10: '5+8-3'

# %%
re=eval(input('enter an expression'))
print(re)
# Out:
# enter an expression 5+5-3
# 7
