# %% [markdown]
# # 3) Mathematical Functions

# %%
import numpy as np

# %%
# Add Two Arrays
g=np.array([5,6,7,8])
added=np.add(g,2)          # Add 2 to each element
print("added 2 to g:", added)
# Out:
# added 2 to g: [ 7  8  9 10]

# %%
# Square each element
squared=np.power(g,2)    
print("squared g:",squared)
# Out:
# squared g: [25 36 49 64]

# %%
# square root of each element
sqrt_val=np.sqrt(g)
print("square root of g:",sqrt_val)
# Out:
# square root of g: [2.23606798 2.44948974 2.64575131 2.82842712]

# %% [markdown]
# # 4) Statistical Functions

# %%
# Mean=average
s=np.array([1,2,3,4])
mean=np.mean(s)
print("mean of s:",mean)
# Out:
# mean of s: 2.5

# %%
# Standard deviation of an array
std_dev = np.std(s)
print("Standard deviation of s:", std_dev)
# Out:
# Standard deviation of s: 1.118033988749895

# %%
# Minimum element of an array
minimum = np.min(s)
print("Min of s:", minimum)
# Out:
# Min of s: 1

# %%
# Maximum element of an array
maximum = np.max(s)
print("Max of s:", maximum)
# Out:
# Max of s: 4

# %% [markdown]
# # 5) Linear Algebra Functions

# %%
# Create a matrix
matrix = np.array([[1, 2], [3, 4]])
matrix
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# # 6) Random Sampling Functions

# %%
# Generate random values between 0 and 1
random_vals = np.random.rand(3)  # Array of 3 random values between 0 and 1
print("Random values:", random_vals)
# Out:
# Random values: [0.43308611 0.45891023 0.01734935]

# %%
# Generate random integers
rand_ints = np.random.randint(0, 10, size=5)  # Random integers between 0 and 10
print("Random integers:", rand_ints)
# Out:
# Random integers: [9 0 6 0 7]

# %%
# Set seed for reproducibility
np.random.seed(0)

# Generate random integers
rand_ints = np.random.randint(0, 10, size=5)  # Random integers between 0 and 10
print("Random integers:", rand_ints)
# Out:
# Random integers: [5 0 3 3 7]

# %% [markdown]
# # 7) Boolean & Logical Functions

# %%
# Check if all elements are True
logical_test = np.array([True, False, True])
all_true = np.all(logical_test)  
print("All elements True:", all_true)
# Out:
# All elements True: False

# %%
# Check if any elements are True
any_true = np.any(logical_test)  
print("Any elements True:", any_true)
# Out:
# Any elements True: True

# %% [markdown]
# # 8) Set operators

# %%
# Intersection of two arrays
set_a = np.array([1, 2, 3, 4])
set_b = np.array([3, 4, 5, 6])
intersection = np.intersect1d(set_a, set_b)
print("Intersection of a and b:", intersection)
# Out:
# Intersection of a and b: [3 4]

# %%
# Union of two arrays
union = np.union1d(set_a, set_b)
print("Union of a and b:", union)
# Out:
# Union of a and b: [1 2 3 4 5 6]

# %% [markdown]
# # 9) Array Attributes Function

# %%
# Array attributes
a = np.array([1, 2, 3])
shape = a.shape  # Shape of the array
size = a.size    # Number of elements
dimensions = a.ndim  # Number of dimensions
dtype = a.dtype   # Data type of the array

print("Shape of a:", shape)
print("Size of a:", size)
print("Number of dimensions of a:", dimensions)
print("Data type of a:", dtype)
# Out:
# Shape of a: (3,)
# Size of a: 3
# Number of dimensions of a: 1
# Data type of a: int64

# %% [markdown]
# # 10) other functions

# %%
# Create a copy of an array
a = np.array([1, 2, 3])
copied_array = np.copy(a)
print("Copied array:", copied_array)
# Out:
# Copied array: [1 2 3]

# %%
# Size in bytes of an array
array_size_in_bytes = a.nbytes  
print("Size of a in bytes:", array_size_in_bytes)
# Out:
# Size of a in bytes: 24

# %%
# Check if two arrays share memory
shared = np.shares_memory(a, copied_array)
print("Do a and copied_array share memory?", shared)
# Out:
# Do a and copied_array share memory? False

# %% [markdown]
# # IPL Data Analysis

# %%
#Import numpy
import numpy as np

#Seasons
Seasons = ["2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"]
Sdict = {"2015":0,"2016":1,"2017":2,"2018":3,"2019":4,"2020":5,"2021":6,"2022":7,"2023":8,"2024":9}

#Players
Players = ["Sachin","Rahul","Smith","Sami","Pollard","Morris","Samson","Dhoni","Kohli","Sky"]
Pdict = {"Sachin":0,"Rahul":1,"Smith":2,"Sami":3,"Pollard":4,"Morris":5,"Samson":6,"Dhoni":7,"Kohli":8,"Sky":9}

#Salaries
Sachin_Salary = [15946875,17718750,19490625,21262500,23034375,24806250,25244493,27849149,30453805,23500000]
Rahul_Salary = [12000000,12744189,13488377,14232567,14976754,16324500,18038573,19752645,21466718,23180790]
Smith_Salary = [4621800,5828090,13041250,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
Sami_Salary = [3713640,4694041,13041250,14410581,15779912,17149243,18518574,19450000,22407474,22458000]
Pollard_Salary = [4493160,4806720,6061274,13758000,15202590,16647180,18091770,19536360,20513178,21436271]
Morris_Salary = [3348000,4235220,12455000,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
Samson_Salary = [3144240,3380160,3615960,4574189,13520500,14940153,16359805,17779458,18668431,20068563]
Dhoni_Salary = [0,0,4171200,4484040,4796880,6053663,15506632,16669630,17832627,18995624]
Kohli_Salary = [0,0,0,4822800,5184480,5546160,6993708,16402500,17632688,18862875]
Sky_Salary = [3031920,3841443,13041250,14410581,15779912,14200000,15691000,17182000,18673000,15000000]
#Matrix
Salary = np.array([Sachin_Salary, Rahul_Salary, Smith_Salary, Sami_Salary, Pollard_Salary, Morris_Salary, Samson_Salary, Dhoni_Salary, Kohli_Salary, Sky_Salary])

#Games 
Sachin_G = [80,77,82,82,73,82,58,78,6,35]
Rahul_G = [82,57,82,79,76,72,60,72,79,80]
Smith_G = [79,78,75,81,76,79,62,76,77,69]
Sami_G = [80,65,77,66,69,77,55,67,77,40]
Pollard_G = [82,82,82,79,82,78,54,76,71,41]
Morris_G = [70,69,67,77,70,77,57,74,79,44]
Samson_G = [78,64,80,78,45,80,60,70,62,82]
Dhoni_G = [35,35,80,74,82,78,66,81,81,27]
Kohli_G = [40,40,40,81,78,81,39,0,10,51]
Sky_G = [75,51,51,79,77,76,49,69,54,62]
#Matrix
Games = np.array([Sachin_G, Rahul_G, Smith_G, Sami_G, Pollard_G, Morris_G, Samson_G, Dhoni_G, Kohli_G, Sky_G])

#Points
Sachin_PTS = [2832,2430,2323,2201,1970,2078,1616,2133,83,782]
Rahul_PTS = [1653,1426,1779,1688,1619,1312,1129,1170,1245,1154]
Smith_PTS = [2478,2132,2250,2304,2258,2111,1683,2036,2089,1743]
Sami_PTS = [2122,1881,1978,1504,1943,1970,1245,1920,2112,966]
Pollard_PTS = [1292,1443,1695,1624,1503,1784,1113,1296,1297,646]
Morris_PTS = [1572,1561,1496,1746,1678,1438,1025,1232,1281,928]
Samson_PTS = [1258,1104,1684,1781,841,1268,1189,1186,1185,1564]
Dhoni_PTS = [903,903,1624,1871,2472,2161,1850,2280,2593,686]
Kohli_PTS = [597,597,597,1361,1619,2026,852,0,159,904]
Sky_PTS = [2040,1397,1254,2386,2045,1941,1082,1463,1028,1331]
#Matrix
Points = np.array([Sachin_PTS, Rahul_PTS, Smith_PTS, Sami_PTS, Pollard_PTS, Morris_PTS, Samson_PTS, Dhoni_PTS, Kohli_PTS, Sky_PTS])

# %%
Salary    #Identifier Should be called with same name
          # if you give small s in salary its an error
# Out:
# array([[15946875, 17718750, 19490625, 21262500, 23034375, 24806250,
#         25244493, 27849149, 30453805, 23500000],
#        [12000000, 12744189, 13488377, 14232567, 14976754, 16324500,
#         18038573, 19752645, 21466718, 23180790],
#        [ 4621800,  5828090, 13041250, 14410581, 15779912, 14500000,
#         16022500, 17545000, 19067500, 20644400],
#        [ 3713640,  4694041, 13041250, 14410581, 15779912, 17149243,
#         18518574, 19450000, 22407474, 22458000],
#        [ 4493160,  4806720,  6061274, 13758000, 15202590, 16647180,
#         18091770, 19536360, 20513178, 21436271],
#        [ 3348000,  4235220, 12455000, 14410581, 15779912, 14500000,
#         16022500, 17545000, 19067500, 20644400],
#        [ 3144240,  3380160,  3615960,  4574189, 13520500, 14940153,
#         16359805, 17779458, 18668431, 20068563],
#        [       0,        0,  4171200,  4484040,  4796880,  6053663,
#         15506632, 16669630, 17832627, 18995624],
# ...

# %%
Games
# Out:
# array([[80, 77, 82, 82, 73, 82, 58, 78,  6, 35],
#        [82, 57, 82, 79, 76, 72, 60, 72, 79, 80],
#        [79, 78, 75, 81, 76, 79, 62, 76, 77, 69],
#        [80, 65, 77, 66, 69, 77, 55, 67, 77, 40],
#        [82, 82, 82, 79, 82, 78, 54, 76, 71, 41],
#        [70, 69, 67, 77, 70, 77, 57, 74, 79, 44],
#        [78, 64, 80, 78, 45, 80, 60, 70, 62, 82],
#        [35, 35, 80, 74, 82, 78, 66, 81, 81, 27],
#        [40, 40, 40, 81, 78, 81, 39,  0, 10, 51],
#        [75, 51, 51, 79, 77, 76, 49, 69, 54, 62]])

# %%
Points
# Out:
# array([[2832, 2430, 2323, 2201, 1970, 2078, 1616, 2133,   83,  782],
#        [1653, 1426, 1779, 1688, 1619, 1312, 1129, 1170, 1245, 1154],
#        [2478, 2132, 2250, 2304, 2258, 2111, 1683, 2036, 2089, 1743],
#        [2122, 1881, 1978, 1504, 1943, 1970, 1245, 1920, 2112,  966],
#        [1292, 1443, 1695, 1624, 1503, 1784, 1113, 1296, 1297,  646],
#        [1572, 1561, 1496, 1746, 1678, 1438, 1025, 1232, 1281,  928],
#        [1258, 1104, 1684, 1781,  841, 1268, 1189, 1186, 1185, 1564],
#        [ 903,  903, 1624, 1871, 2472, 2161, 1850, 2280, 2593,  686],
#        [ 597,  597,  597, 1361, 1619, 2026,  852,    0,  159,  904],
#        [2040, 1397, 1254, 2386, 2045, 1941, 1082, 1463, 1028, 1331]])

# %%
Sdict
# Out:
# {'2015': 0,
#  '2016': 1,
#  '2017': 2,
#  '2018': 3,
#  '2019': 4,
#  '2020': 5,
#  '2021': 6,
#  '2022': 7,
#  '2023': 8,
#  '2024': 9}

# %%
Pdict
# Out:
# {'Sachin': 0,
#  'Rahul': 1,
#  'Smith': 2,
#  'Sami': 3,
#  'Pollard': 4,
#  'Morris': 5,
#  'Samson': 6,
#  'Dhoni': 7,
#  'Kohli': 8,
#  'Sky': 9}

# %%
Games[5]
# Out:
# array([70, 69, 67, 77, 70, 77, 57, 74, 79, 44])

# %%
Games[5,3]
# Out:
# np.int64(77)

# %%
Games[0]
# Out:
# array([80, 77, 82, 82, 73, 82, 58, 78,  6, 35])

# %%
Pdict # 0 is sachin
# Out:
# {'Sachin': 0,
#  'Rahul': 1,
#  'Smith': 2,
#  'Sami': 3,
#  'Pollard': 4,
#  'Morris': 5,
#  'Samson': 6,
#  'Dhoni': 7,
#  'Kohli': 8,
#  'Sky': 9}

# %%
Salary[0] # Sachins Salary
# Out:
# array([15946875, 17718750, 19490625, 21262500, 23034375, 24806250,
#        25244493, 27849149, 30453805, 23500000])

# %%
# For 80 Games Sachin Salary is 15946875
# Find Out Sachin One Match Salary

Salary[0] / Games[0]
# Out:
# array([ 199335.9375    ,  230113.63636364,  237690.54878049,
#         259298.7804878 ,  315539.38356164,  302515.24390244,
#         435249.87931034,  357040.37179487, 5075634.16666667,
#         671428.57142857])

# %%
np.round(Salary[0] / Games[0] )
# Out:
# array([ 199336.,  230114.,  237691.,  259299.,  315539.,  302515.,
#         435250.,  357040., 5075634.,  671429.])

# %% [markdown]
# # Lets Visualize the data

# %%
import warnings 
warnings.filterwarnings('ignore')

# in word document even though the word is correct it will give red underline mark
# so to ingnore those OS unwanted errors we use this code

# %%
# matplotlib is a visualization library
import matplotlib.pyplot as plt

# %%
Salary[0]
# Out:
# array([15946875, 17718750, 19490625, 21262500, 23034375, 24806250,
#        25244493, 27849149, 30453805, 23500000])

# %%
plt.plot(Salary[0])
# Please have a look at shift tab options
# if you got error using plt.plot(Salary[0]), use plt.show()

# %%
# if you press 'shift tab' in plot & scroll down you can see the colour options, select Colour
# Color changes
plt.plot(Salary[0],color='red')

# %%
# plt.plot(Salary[0],color='red')
# instead of writing color='red' you can write c='r' in shortcut form
plt.plot(Salary[0],c='r')

# %%
plt.plot(Salary[0],c='r', ls='--')

# shift tab on plot scroll down you can see line style

# %%
plt.plot(Salary[0],c='r', ls='--', marker='o')

# shift tab and select marker style

# %%
Games[0]
# Sachin salary increased till 2023 and decreased beacause he played less matches after that
# Out:
# array([80, 77, 82, 82, 73, 82, 58, 78,  6, 35])

# %% [markdown]
# # Nov 03 2025

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']= 6,3

# the above visual is occupying more screen space, to reduce it to smaller size we use this

# %%
plt.plot(Salary[0],c='r', ls='--', marker='o', ms= 3)
plt.show()

# ms = marker size

# %%
plt.plot(Salary[0],c='r',ls='--',marker='s',ms=5)
plt.xticks(list(range(0,10)),Seasons)
plt.show()

# xticks is to Show X axis Values, Yticks is to show y axis values

# %%
plt.plot(Salary[0],c='r',ls='--',marker='s',ms=5)
plt.xticks(list(range(0,10)),Seasons,rotation='vertical')
plt.show()
# if you want to show x axis values in vertical

# %%
plt.plot(Salary[0],c='r',ls='--',marker='s',ms=5)
plt.xticks(list(range(0,10)),Seasons,rotation='horizontal')
plt.show()
# if you want to show y axis values in Horizontal

# %%
plt.plot(Salary[0],c='r',ls='--',marker='s',ms=5)
plt.plot(Salary[1],c='k',ls=':',marker='o',ms=4)
plt.xticks(list(range(0,10)),Seasons,rotation='horizontal')
plt.show()
# if you want to compare two players

# %%
# salary of player 1 is good but performance has ups and downs, player 2 salary is less but
# his performance is increasing only no decreasing

# %%
plt.plot(Salary[0],c='r',ls='--',marker='s',ms=5,label=Players[0])
plt.plot(Salary[1],c='k',ls=':',marker='o',ms=4,label=Players[1])
plt.plot(Salary[2],c='g',ls='-.',marker='^',ms=5,label=Players[2])
plt.xticks(list(range(0,10)),Seasons,rotation='horizontal')
plt.legend()
plt.show()
# if you want to compare multiple players with lables showing you must use legend code

# %%
#plt.legend= automatic detection of elements to be shown in the legend
#if you remove legend you wont get any graph. legend detects graph colors

# %%
plt.plot(Salary[0], c='Green', ls = '--', marker = 's', ms = 7, label = Players[0])
plt.plot(Salary[1], c='Blue', ls = '--', marker = 'o', ms = 5, label = Players[1])
plt.plot(Salary[2], c='purple', ls = '--', marker = '^', ms = 8, label = Players[2])
plt.plot(Salary[3], c='Red', ls = '--', marker = 'd', ms = 8, label = Players[3])
plt.legend(loc = 'lower right',bbox_to_anchor=(0,1) ) 
plt.xticks(list(range(0,10)), Seasons,rotation='vertical')

plt.show()

# if you want to set the position of the label

# %%
plt.plot(Games[0], c='Green', ls = '--', marker = 's', ms = 7, label = Players[0])
plt.plot(Games[1], c='Blue', ls = '--', marker = 'o', ms = 7, label = Players[1])
plt.plot(Games[2], c='Green', ls = '--', marker = '^', ms = 7, label = Players[2])
plt.plot(Games[3], c='Red', ls = '--', marker = 'D', ms = 7, label = Players[3])
plt.plot(Games[4], c='Black', ls = '--', marker = 's', ms = 7, label = Players[4])
plt.plot(Games[5], c='Blue', ls = '--', marker = 'o', ms = 7, label = Players[5])
plt.plot(Games[6], c='red', ls = '--', marker = '^', ms = 7, label = Players[6])
plt.plot(Games[7], c='Green', ls = '--', marker = 'd', ms = 7, label = Players[7])
plt.plot(Games[8], c='Red', ls = '--', marker = 's', ms = 7, label = Players[8])
plt.plot(Games[9], c='Blue', ls = '--', marker = 'o', ms = 7, label = Players[9])

plt.legend(loc = 'lower right',bbox_to_anchor=(0.5,1) )
plt.xticks(list(range(0,10)), Seasons,rotation='vertical')

plt.show()

# %%
# if data is big, python cant visualize. even though it visualize it doesnot make sense
# that why we use bi tool called power bi or tableau for visualizations

# %% [markdown]
# # Nov 04 2025
