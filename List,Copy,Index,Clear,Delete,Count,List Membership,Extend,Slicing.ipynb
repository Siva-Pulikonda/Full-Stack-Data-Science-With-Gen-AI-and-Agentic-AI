# %% [markdown]
# # Oct 22 2025 Start

# %% [markdown]
# # Python Datastructure

# %% [markdown]
# # List

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append()   # append takes an argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 l.append()
#
# TypeError: list.append() takes exactly one argument (0 given)

# %%
l.append(10)   # No of times you execute this, no of 10's it will be added to your list
l              # append always add at the end of the list
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)

l
# Out:
# [10, 20, 30, 40]

# %%
len(l)
# Out:
# 4

# %%
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l1=[10,3.4,'ten',True,1+2j]  # you can add all types of datatypes to the list
l1
# Out:
# [10, 3.4, 'ten', True, (1+2j)]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50]
# [10, 3.4, 'ten', True, (1+2j)]

# %%
print(len(l))
print(len(l1))
# Out:
# 5
# 5

# %%
print(id(l))    # id's will be different 
print(id(l1))
# Out:
# 3003153828352
# 3003208948928

# %% [markdown]
# # Copy

# %%
l2= l1.copy()    # you can copy one list to another list
l2
# Out:
# [10, 3.4, 'ten', True, (1+2j)]

# %%
l1==l2
# Out:
# True

# %% [markdown]
# # Index

# %%
l[:]    # this will print the total list
# Out:
# [10, 20, 30, 40, 50]

# %%
l[0]    # index starts with zero so it will print first value
# Out:
# 10

# %%
l[10]   # list consists of only 5 values but you asked for 10th index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 l[10]
#
# IndexError: list index out of range

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l[0]=100   # here i am replacing one value with another value using index 
l          # This concept is called changable or mutable or hashable
# Out:
# [100, 20, 30, 40, 50]

# %%
l[-1] = 'Jan'    # -1, -2 these are backward indexing 
l                # Backward index starts with -1
# Out:
# [100, 20, 30, 40, 'Jan']

# %%
l[-2] ='Feb'
l
# Out:
# [100, 20, 30, 'Feb', 'Jan']

# %%
l.append('Mar')
l
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar']

# %%
l.append(77)    # append always adds at the end of the list
l
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar', 77]

# %%
l.append(30)   # Duplicates are allowed in the list
l
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar', 77, 30]

# %%
l2
# Out:
# [10, 3.4, 'ten', True, (1+2j)]

# %%
# Indexing , Slicing , Duplicates are allowed in the list

# %% [markdown]
# # Clear

# %%
l2
# Out:
# [10, 3.4, 'ten', True, (1+2j)]

# %%
l2.clear()   # clear will clear the values from the list
l2
# Out:
# []

# %% [markdown]
# # Delete

# %%
del l2   # this will delete l2 list completely

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %% [markdown]
# # Count

# %%
l.count(100)
# Out:
# 1

# %%
l.append(10)
l
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar', 77, 30, 10]

# %%
l.append(10)   # Now l contains two 10's now we will count
l
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar', 77, 30, 10, 10]

# %%
l.count(10)
# Out:
# 2

# %%
l.count(50)    # 50 is not there in the list so we will get Zero
# Out:
# 0

# %% [markdown]
# # List Membership

# %%
100 in l   # Does 100 is a member of l Yes So True
# Out:
# True

# %%
500 in l   # 500 is not a member of l No so False
# Out:
# False

# %% [markdown]
# # Extend

# %%
l
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar', 77, 30, 10, 10]

# %%
l1
# Out:
# [10, 3.4, 'ten', True, (1+2j)]

# %%
l2=[]
l2
# Out:
# []

# %%
l2.extend(l)  # extend will extend on list values to another list

# %%
l2
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar', 77, 30, 10, 10]

# %%
l2.extend(l1)   
l2
# Out:
# [100,
#  20,
#  30,
#  'Feb',
#  'Jan',
#  'Mar',
#  77,
#  30,
#  10,
#  10,
#  10,
#  3.4,
#  'ten',
#  True,
#  (1+2j)]

# %% [markdown]
# # Index

# %%
l
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar', 77, 30, 10, 10]

# %%
l.index('Jan')  # This will find the position of element
# Out:
# 4

# %%
l4= [10,20,30,30,40,50]
l4
# Out:
# [10, 20, 30, 30, 40, 50]

# %%
l4.index(30)    # it will find first 30 value psoistion
# Out:
# 2

# %% [markdown]
# # Forward Indexing

# %%
l[:]      # Print all Values
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar', 77, 30, 10, 10]

# %%
l2
# Out:
# [100,
#  20,
#  30,
#  'Feb',
#  'Jan',
#  'Mar',
#  77,
#  30,
#  10,
#  10,
#  10,
#  3.4,
#  'ten',
#  True,
#  (1+2j)]

# %%
l2[0:6]    # will print from Zero index to sixth index
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar']

# %%
l2[3:10]   # Print 3rd index to 10 th index
# Out:
# ['Feb', 'Jan', 'Mar', 77, 30, 10, 10]

# %%
l2[::2]    # will skip every second index till the end of the list
# Out:
# [100, 30, 'Jan', 77, 10, 10, 'ten', (1+2j)]

# %%
l2[::3]    # will skip every third index till the end of the list
# Out:
# [100, 'Feb', 77, 10, 'ten']

# %% [markdown]
# # Backward Indexing

# %%
l2
# Out:
# [100,
#  20,
#  30,
#  'Feb',
#  'Jan',
#  'Mar',
#  77,
#  30,
#  10,
#  10,
#  10,
#  3.4,
#  'ten',
#  True,
#  (1+2j)]

# %%
l2[-5]     # Print 5th index from reverse
# Out:
# 10

# %%
l2[:-9]    # Print from 9th index to end of list in reverse
# Out:
# [100, 20, 30, 'Feb', 'Jan', 'Mar']

# %%
l2[-4:]   # this will print last four elements in order in backward index
# Out:
# [3.4, 'ten', True, (1+2j)]

# %%
l2[3:-2]   # Skips 0,1,2 indexes elements and skips -1,-2 elements and print the rest
# Out:
# ['Feb', 'Jan', 'Mar', 77, 30, 10, 10, 10, 3.4, 'ten']

# %%
l2[::-3]   # Skip every Third index in reverse order
# Out:
# [(1+2j), 3.4, 10, 'Mar', 30]

# %% [markdown]
# # Remove

# %%
l1
# Out:
# [10, 3.4, 'ten', True, (1+2j)]

# %%
l1.remove(1+2j)   # this removes the mentioned element
l1
# Out:
# [10, 3.4, 'ten', True]

# %% [markdown]
# # Oct 22 2025 End
