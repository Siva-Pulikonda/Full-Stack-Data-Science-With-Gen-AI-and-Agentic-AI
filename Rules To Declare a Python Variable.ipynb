# %% [markdown]
# # Oct 14 2025 Start

# %% [markdown]
# # Rules To Create a Variable in Python

# %%
import sys
sys.version  # This will give Current version of aanaconda
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # python variable = identifier # object
# # syntax (variable = value)

# %%
v=8
v
# Out:
# 8

# %%
var=8
VAR     # Python is case Sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 var=8
# ----> 2 VAR
#
# NameError: name 'VAR' is not defined

# %%
var
# Out:
# 8

# %%
v@=27   # Special Symbols are not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 v@=27
#
# TypeError: unsupported operand type(s) for @=: 'int' and 'int'

# %%
v_= 10
v_        # Only Underscore is allowed
# Out:
# 10

# %%
1var=25   # variable should not start with digits
# Out:
#   Cell In[11], line 1
#     1var=25
#     ^
# SyntaxError: invalid decimal literal

# %%
var1=24    # variable can end with digit
var1
# Out:
# 24

# %%
var2_=20
var2_
# Out:
# 20

# %%
import keyword   # These are the 35 keywords we are going to use in python
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
for=15  # keywords will not work as a variable
# Out:
#   Cell In[17], line 1
#     for=15  # keywords will not work as a variable
#        ^
# SyntaxError: invalid syntax

# %%
FOR = 15
FOR      # Capital FOR is not a keyword So this Will Work
# Out:
# 15

# %%
age=25    # Here Age is a Variable and it store integer value
print(age)
# Out:
# 25

# %%
name='Siva'   # Here name is a variable and it store string
print(name)
# Out:
# Siva

# %%
price=19.99   # Here price is a variable and Store float value
print(price)

# %%
active=True    # here avtive is a variable and stores boolean value
print(active)
# Out:
# True

# %%
# Storing a Value
a=10
print(a)
# Out:
# 10

# %%
a=5
b=5
result =a+b
print(result)
# Out:
# 10

# %%
score=50
print(score)
# Out:
# 50

# %%
score=100 # previous score 50 is replaced by 100
print(score)

# %%
first_name='Siva'
last_name='Pulikonda'

full_name=first_name+ " " + last_name
print(full_name)
# Out:
# Siva Pulikonda

# %%
length=10
width=5
area=length*width
print(area)
# Out:
# 50

# %% [markdown]
# # Oct 14 2025 Ends
