# %% [markdown]
# # Oct 15 2025 Start

# %%
False = 25
False        # Error Because Keywords cannot be used as variable
# Out:
#   Cell In[3], line 1
#     False = 25
#     ^
# SyntaxError: cannot assign to False

# %%
false= 25 
false      # Output came because in false f is small and python variable is case sensitive
# Out:
# 25

# %%
i=5
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
price = 120.99
price
# Out:
# 120.99

# %%
type(price)
# Out:
# float

# %%
i
price    # when you want to print more than one output use print option otherwise you will get only last variable output
# Out:
# 120.99

# %%
print(i)
print(price)
# Out:
# 5
# 120.99

# %%
i + price
# Out:
# 125.99

# %%
i - price
# Out:
# -115.99

# %%
i * price
# Out:
# 604.9499999999999

# %% [markdown]
# # Boolean

# %%
True   # in Boolean True = 1 and False = 0
# Out:
# True

# %%
False
# Out:
# False

# %%
True+False
# Out:
# 1

# %%
True+True
# Out:
# 2

# %%
False+False
# Out:
# 0

# %%
True * False
# Out:
# 0

# %%
True/True
# Out:
# 1.0

# %%
True//True
# Out:
# 1

# %%
s='hello'
s
# Out:
# 'hello'

# %%
s1="hello"
s1             # string is always declared with single, double, triple qotations
# Out:
# 'hello'

# %%
s2='''hello'''
s2            # we mostly use triple qotations for multi line comments
# Out:
# 'hello'

# %%
s3='''hello
            team'''
s3                      # here \n means next line
# Out:
# 'hello\n            team'

# %%
# complex syntax = a + bj
# a= real part, b= imaginary part, j= square root of -1

c=10+2j
c
# Out:
# (10+2j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 2.0

# %%
a=10+30j
b=50+40j

print(a)
print(b)
# Out:
# (10+30j)
# (50+40j)

# %%
print(a+b)
# Out:
# (60+70j)

# %%
print(a-b)
# Out:
# (-40-10j)

# %%
print(a*b)
# Out:
# (-700+1900j)

# %%
# Python Data Types Completed

# %% [markdown]
# # Oct 15 2025 End
