# %% [markdown]
# # Oct 18 2025

# %% [markdown]
# # Python Operators

# %%
# Arithmetic Operator (+, -, *, /, //, %, **)
# Assignment Operator (=, +=, -=, *=, /=, //=)
# Relational Operator (>, <, >=, <=, ==, !=)
# logical Operator    (and, or, not)
# Unary Operator      (-)

# %% [markdown]
# # 1) Arithmetic Operator

# %%
x=10
y=5

# %%
x1,y1= 15,20   # you can define in two ways

# %%
x1+y1
# Out:
# 35

# %%
y1-x1
# Out:
# 5

# %%
x1*y1
# Out:
# 300

# %%
y1/x1     # Float
# Out:
# 1.3333333333333333

# %%
y1//x1   # integer
# Out:
# 1

# %%
y1%x1   # remainder
# Out:
# 5

# %%
x**y   # ** means square so 10 square 5
# Out:
# 100000

# %%
5**2   # 5 Square
# Out:
# 25

# %%
9**3   # 9 Cube
# Out:
# 729

# %% [markdown]
# # 2) Assignment Operator

# %%
x=2
x
# Out:
# 2

# %%
x=x+2
x
# Out:
# 4

# %%
x+=2
x
# Out:
# 6

# %%
x*=2
x
# Out:
# 12

# %%
x-=2
x
# Out:
# 10

# %%
x/=2
x
# Out:
# 5.0

# %%
x//=2    # here output is 2.0 but not 2.5 why 
x        # It removes the decimal part by rounding down to the nearest integer.
# Out:
# 2.0

# %% [markdown]
# # 3) Relational Operators

# %%
# we use this operator for comparing

# %%
a=5
b=7

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a==b   # for = we have to use double equal to ==
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
b=5  # i changed b=7 to b=5 value so now a==b

# %%
a==b
# Out:
# True

# %%
print(a)
print(b)
# Out:
# 5
# 5

# %%
a>b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
b=7

# %%
a!=b
# Out:
# True

# %% [markdown]
# # 4) Logical Operator

# %%
# and = when both conditions are true then the result is true
# or = when any one condition is true then the result is true

# %%
a=10
b=15

# %%
a<8 and b>8
# Out:
# False

# %%
a<8 or b>8
# Out:
# True

# %%
x=False
x
# Out:
# False

# %%
x1=not x
x1
# Out:
# True

# %%
not x1
# Out:
# False

# %% [markdown]
# # 5) Unary Operator

# %%
# uni =1  unary means 1
# bi =2
# tri =3
# Qudra =4
# Penta =5
# Hexa =6
# Septa =7

# %%
n=7
n
# Out:
# 7

# %%
m=-(n)  # Negation
m
# Out:
# -7

# %% [markdown]
# # Compliment Operator

# %%
~ 12  # best way to store negative values in the system is using compliment operator
# Out:
# -13

# %%
~ 55
# Out:
# -56

# %% [markdown]
# # Bit Wise and Operator

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
#  0b11001 # 1*2^4+ 1*2^3+ 0*2^2+ 0*2^1+ 1*2^0 = 25
#  Power Applied in Backward Direction
