# %% [markdown]
# # Read the Image and convert the image into array

# %%
import numpy as np    # Array

# %%
import matplotlib.pyplot as plt   #Visualization

# %%
from PIL import Image   # python image library

# %%
# Download any jpg or jpeg or png image from internet and store it in a location and while reading the image give the image location

# %%
imageluffy=Image.open(r'C:\Users\sivap\Practice Folder\November\luffy.jpeg')

# %%
imageluffy
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
imagekrishna=Image.open(r'C:\Users\sivap\Practice Folder\November\krishna.PNG')
imagekrishna
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
print(type(imageluffy))
print(type(imagekrishna))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
luffy_arr=np.asarray(imageluffy)    # by using this image will be converted to array
luffy_arr
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 39,   0,   1],
#         [ 31,   3,   2],
#         [ 23,   5,   1],
#         ...,
#         [175, 174, 180],
#         [175, 174, 180],
#         [175, 174, 180]],
#
#        [[ 40,   0,   1],
#         [ 32,   2,   2],
#         [ 24,   5,   1],
#         ...,
#         [174, 173, 179],
#         [174, 173, 179],
#         [174, 173, 179]],
#
#        [[ 40,   0,   1],
#         [ 32,   2,   2],
#         [ 25,   4,   1],
# ...

# %%
krishna_arr=np.asarray(imagekrishna)    # This will convert image into array
krishna_arr
# Out:
# array([[[ 17,  27,  43, 255],
#         [ 17,  27,  43, 255],
#         [ 17,  27,  43, 255],
#         ...,
#         [ 21,  23,  29, 255],
#         [ 21,  23,  29, 255],
#         [ 21,  23,  29, 255]],
#
#        [[ 17,  27,  43, 255],
#         [ 17,  27,  43, 255],
#         [ 17,  27,  43, 255],
#         ...,
#         [ 20,  21,  28, 255],
#         [ 20,  21,  28, 255],
#         [ 20,  21,  28, 255]],
#
#        [[ 17,  27,  43, 255],
#         [ 17,  27,  43, 255],
#         [ 17,  27,  43, 255],
#         ...,
#         [ 20,  21,  29, 255],
#         [ 20,  21,  29, 255],
#         [ 20,  21,  29, 255]],
#
#        ...,
#
#        [[ 72,  41,  34, 255],
#         [ 72,  41,  34, 255],
#         [ 72,  41,  34, 255],
#         ...,
#         [ 16,   5,   3, 255],
#         [ 16,   5,   3, 255],
#         [ 16,   5,   3, 255]],
#
#        [[ 72,  41,  33, 255],
#         [ 72,  41,  33, 255],
#         [ 72,  41,  33, 255],
#         ...,
#         [ 16,   5,   3, 255],
# ...

# %%
plt.imshow(luffy_arr)    # This will give you dimensions of the image
plt.show()

# %%
plt.imshow(krishna_arr)    # This will give you dimensions of the image
plt.show()

# %%
luffy_arr.shape      # shape will give you Height, width and channels. channels means Red, Green, Blue(RGB)
# Out:
# (168, 300, 3)

# %%
krishna_arr.shape
# Out:
# (1080, 1920, 4)

# %% [markdown]
# # Nov 01 2025
