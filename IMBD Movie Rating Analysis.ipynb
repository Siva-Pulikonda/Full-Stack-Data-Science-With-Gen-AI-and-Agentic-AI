# %% [markdown]
# # Nov 25 2025

# %% [markdown]
# # IMBD Movie Rating Analysis

# %%
import pandas as pd

# %%
movies=pd.read_csv(r'C:\Users\sivap\Practice Folder\November\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movies)
# Out:
# 559

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.1.3

# %%
import pandas
print(pandas.__version__)
# Out:
# 2.2.3

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
# Now we are going to change movie names so everyone can understand
movies.columns=['Film','Genre','CriticRating','AudienceRating','BudgetinMillions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetinMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# 4                20  2009

# %%
movies.info()     # if you see year datatype is int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    object
#  1   Genre             559 non-null    object
#  2   CriticRating      559 non-null    int64
#  3   AudienceRating    559 non-null    int64
#  4   BudgetinMillions  559 non-null    int64
#  5   Year              559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()     # year is showing mean, median, min, max, for year but year dont have them 
                      # so we convert year int to object
# Out:
#        CriticRating  AudienceRating  BudgetinMillions         Year
# count    559.000000      559.000000        559.000000   559.000000
# mean      47.309481       58.744186         50.236136  2009.152057
# std       26.413091       16.826887         48.731817     1.362632
# min        0.000000        0.000000          0.000000  2007.000000
# 25%       25.000000       47.000000         20.000000  2008.000000
# 50%       46.000000       58.000000         35.000000  2009.000000
# 75%       70.000000       72.000000         65.000000  2010.000000
# max       97.000000       96.000000        300.000000  2011.000000

# %%
movies.Film=movies.Film.astype('category')  # astype is we convert system build in datatype to user defined datatype
                                            # after using this film object is converted to category

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    category
#  1   Genre             559 non-null    object
#  2   CriticRating      559 non-null    int64
#  3   AudienceRating    559 non-null    int64
#  4   BudgetinMillions  559 non-null    int64
#  5   Year              559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre=movies.Genre.astype('category')   # Genre is converted to category

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    category
#  1   Genre             559 non-null    category
#  2   CriticRating      559 non-null    int64
#  3   AudienceRating    559 non-null    int64
#  4   BudgetinMillions  559 non-null    int64
#  5   Year              559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movies.Year=movies.Year.astype('category')    # Year is converted to category

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    category
#  1   Genre             559 non-null    category
#  2   CriticRating      559 non-null    int64
#  3   AudienceRating    559 non-null    int64
#  4   BudgetinMillions  559 non-null    int64
#  5   Year              559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()        # Now it wont display category attributes
# Out:
#        CriticRating  AudienceRating  BudgetinMillions
# count    559.000000      559.000000        559.000000
# mean      47.309481       58.744186         50.236136
# std       26.413091       16.826887         48.731817
# min        0.000000        0.000000          0.000000
# 25%       25.000000       47.000000         20.000000
# 50%       46.000000       58.000000         35.000000
# 75%       70.000000       72.000000         65.000000
# max       97.000000       96.000000        300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='hex')
# jointplot is a scatter plot which finds difference between audience and critics
# you can see audience rating is more dominating than critic ratings

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='scatter')  # shift + tab on scatter you can find different types of graphs

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='reg')

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='kde')

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='hist')

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='resid')

# %% [markdown]
# # distplot

# %%
m1=sns.distplot(movies.AudienceRating)

# %%
m1=sns.distplot(movies.CriticRating)

# %%
sns.set_style('darkgrid')    # this will change the background

# %%
m1=sns.distplot(movies.CriticRating)

# %%
plt.hist(movies.BudgetinMillions)
plt.show()

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',fit_reg=False)
# if x,y have same colours you will get confused, so we use hue to change colours

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',
                fit_reg=False,hue='Genre')

# %%
ax=plt.subplots(3,3,figsize=(10,8))    # 3,3 means 3 rows and 3 columns

# %%
w=sns.boxplot(data=movies,x='Genre',y='CriticRating')

# %%
z=sns.violinplot(data=movies,x='Genre',y='CriticRating')   # used for to know average of values

# %% [markdown]
# # Nov 26 2025

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.scatter,'CriticRating','AudienceRating')

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.hist,'BudgetinMillions')
